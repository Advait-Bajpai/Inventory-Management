# %%
# Importing Libraries
import json
import time

# Loading the Inventory Records from JSON to String
ch = 'Y'
fd = open('Records.json','r')
js = fd.read()
fd.close()

# Converting string records to JSON/Dictionariese
record = json.loads(js)

# Displaying the Menu
print("--------------------MENU---------------------")
for key in record.keys():
    print(key, record[key]['Name'], record[key]['Price'], record[key]['Qn'])
print("---------------------------------------------")
print('')

# Taking User Inputs about thier purchases and User details
ui_name = str(input("Enter your name    : "))
ui_mail = str(input("Enter Mail ID      : "))
ui_ph   = str(input("Enter Phone No     :  "))
ui_pr   = str(input("Enter product ID   : "))
ui_qn   = int(input("Enter Quantity     : "))

print("---------------------------------------------")
print('')

# If we are having equal or more quantity than user wants
if (record[ui_pr]['Qn'] >= ui_qn):

#     Displaying the purchase details
    print("Name      : ", record[ui_pr]["Name"])
    print("Price (Rs): ", record[ui_pr]["Price"])
    print("Quantity  : ", ui_qn)
    print("---------------------------------------------")
    print("Billing   : ", ui_qn * record[ui_pr]["Price"], "Rs")
    print("---------------------------------------------")

#     Updating the Records Dictionary
    record[ui_pr]['Qn'] = record[ui_pr]['Qn'] - ui_qn
    
#     Generating the sales structure in csv
    sale = '1'+","+ui_name+","+ui_mail+","+ui_ph+","+ui_pr+","+record[ui_pr]["Name"]+","+str(ui_qn)+","+str(record[ui_pr]["Price"])+","+str(ui_qn * record[ui_pr]["Price"])+","+time.ctime()

# If we're not having enought quantities
else:
#     Displaying Info about the quantity
    print("Sorry, We're not having enough quanity of product in our Inventory.")
    print("We're only having " + str(record[ui_pr]['Qn']) + " quantity.")
    print("---------------------------------------------")
#     If user wants to purchase the whole inventory for that product
    ch == str(raw_input("Press Y to purchase: "))
    
    if(ch == "Y" or ch == 'y'):
#     Displaying the purchase details
        print("---------------------------------------------")
        print("Name      : ", record[ui_pr]["Name"])
        print("Price (Rs): ", record[ui_pr]["Price"])
        print("Quantity  : ", record[ui_pr]['Qn'])
        print("---------------------------------------------")
        print("Billing   : ", record[ui_pr]['Qn'] * record[ui_pr]["Price"], "Rs")
        print("---------------------------------------------")
        
#     Updating the Records Dictionary
        record[ui_pr]['Qn'] = 0
        
        sale = '1'+","+ui_name+","+ui_mail+","+ui_ph+","+ui_pr+","+record[ui_pr]["Name"]+","+str(record[ui_pr]['Qn'])+","+str(record[ui_pr]["Price"])+","+str(record[ui_pr]['Qn'] * record[ui_pr]["Price"])+","+time.ctime()
        
    else:
        print("Thanks!")

#         Converting dictionary to string
js = json.dumps(record)
# Saving records in JSON file
fd = open('Records.json','w')
fd.write(js)
fd.close()
# Saving records in sales file
fd = open('Sales.txt','a')
fd.write(sale)
fd.close()

print('')
print("---------------------------------------------")
print("  Thanks for your order, Inventory Updated!  ")
print("---------------------------------------------")
# Out:
# --------------------MENU---------------------
# 1001 5 Star 10 200
# 1002 Bar-One 20 100
# 1003 Candy 2 1000
# 1004 Chocolate Cake 550 50
# 1005 Blueberry Cake 650 50
# ---------------------------------------------
#
# Enter your name    : Hello
# Enter Mail ID      : Hello.cake@mail.com
# Enter Phone No     :  1234567890
# Enter product ID   : 1001
# Enter Quantity     : 10
# ---------------------------------------------
#
# Name      :  5 Star
# Price (Rs):  10
# Quantity  :  10
# ---------------------------------------------
# Billing   :  100 Rs
# ---------------------------------------------
#
# ---------------------------------------------
#   Thanks for your order, Inventory Updated!
# ---------------------------------------------
